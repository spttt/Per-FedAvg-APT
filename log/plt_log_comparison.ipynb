# %%
from plot_utils import *

# %%
plot5figure_CICIDS2017(log_path='log/2023-10-30-14-35-08',
                       csv_list=[
                           'test_log_2000_finetune_lr_None_alpha_0.01.csv',
                           'test_log_0_finetune_lr_None_alpha_0.01.csv',
                           'test_log_2000_finetune_lr_0.1_alpha_0.01.csv',
                       ],
                       strlist=['acc'], unknow_nums=[0, 1, 2, 3, 4],
                       csv_legend_list=[
                           'Meta init, normal training',
                           'Default init, normal training',
                           'Meta init, fine-tuning',
                       ])
# Out:
# unknow_num = 0
# acc:0.8596, f1:0.8556, (Meta init, normal training)
# acc:0.6980, f1:0.6494, (Default init, normal training)
# acc:0.8064, f1:0.7987, (Meta init, fine-tuning)
#
# unknow_num = 1
# acc:0.8407, f1:0.8043, (Meta init, normal training)
# acc:0.7062, f1:0.6263, (Default init, normal training)
# acc:0.7919, f1:0.7081, (Meta init, fine-tuning)
#
# unknow_num = 2
# acc:0.8295, f1:0.8006, (Meta init, normal training)
# acc:0.6723, f1:0.5634, (Default init, normal training)
# acc:0.7404, f1:0.6607, (Meta init, fine-tuning)
#
# unknow_num = 3
# acc:0.7963, f1:0.7601, (Meta init, normal training)
# acc:0.7244, f1:0.6323, (Default init, normal training)
# acc:0.7304, f1:0.6550, (Meta init, fine-tuning)
#
# unknow_num = 4
# acc:0.8192, f1:0.7601, (Meta init, normal training)
# acc:0.7935, f1:0.6577, (Default init, normal training)
# acc:0.6710, f1:0.5723, (Meta init, fine-tuning)

# %%
plot1figure_dapt2020(log_path='log/2023-10-29-04-43-07',
                     M_NT='test_log_2000_finetune_lr_None_alpha_0.01.csv',
                     D_NT='test_log_0_finetune_lr_None_alpha_0.01.csv',
                     M_FT='test_log_2000_finetune_lr_0.1_alpha_0.01.csv',
                     )
# Out:
# acc:0.7726, f1:0.6513, (Meta init, normal training )
# acc:0.6371, f1:0.4189, (Default init, normal training )
# acc:0.5960, f1:0.4918, (Meta init, fine-tuning )
